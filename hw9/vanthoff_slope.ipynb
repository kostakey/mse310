# %% [markdown]
# # van't Hoff Initial Liquidus Slope

# %%
R=8.314
Tm=800.0; DH=8000.0
slope = -R*Tm*Tm/DH
print('dT/dX_B at X_B→0 ≈', slope, 'K per mole fraction')
# Out:
# dT/dX_B at X_B→0 ≈ -665.12 K per mole fraction
