# %% [markdown]
# # Standard-State Bridge (Solid ↔ Liquid)

# %%
import numpy as np
R=8.314
Tm=1200.0; DH=12000.0; T=1000.0
DG = DH*(1 - T/Tm)
ratio = np.exp(DG/(R*T))
print('ΔG_m° =',DG,'J/mol; a_s/a_l =',ratio)
# Out:
# ΔG_m° = 1999.9999999999995 J/mol; a_s/a_l = 1.2719588258508217
